# %%
import pandas as pd
import  numpy as np
from sklearn.preprocessing import  StandardScaler
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\mabdraman\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\mabdraman\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %% [markdown]
# ## 📊 Dictionnaire des variables
#
# | Variable                | Description (FR)                                                                 |
# |--------------------------|----------------------------------------------------------------------------------|
# | SEXE                    | Sexe de l’emprunteur (H/F)                                                       |
# | AGE_JOURS               | Âge de l’emprunteur en jours (valeur négative, distance à la date de référence)  |
# | ANCIENNETE_EMPLOI_JOURS | Ancienneté dans l’emploi actuel (en jours, valeur négative)                      |
# | ANCIENNETE_REGISTRE_JOURS| Ancienneté de l’enregistrement officiel de l’identité (jours, valeur négative)   |
# | ANCIENNETE_IDENTITE_JOURS| Nombre de jours depuis la délivrance ou mise à jour de la pièce d’identité       |
# | NIVEAU_ETUDES           | Niveau d’études atteint (secondaire, supérieur, etc.)                            |
# | STATUT_FAMILIAL         | Statut familial (marié, célibataire, divorcé, etc.)                              |
# | TYPE_LOGEMENT           | Type de logement (propriétaire, locataire, avec parents, etc.)                   |
# | NB_ENFANTS              | Nombre d’enfants déclarés                                                        |
# | NB_MEMBRES_FAMILLE      | Nombre total de membres dans le foyer                                            |
# | REVENU_TOTAL            | Revenu annuel total du ménage                                                    |
# | MONTANT_CREDIT          | Montant total du crédit demandé                                                  |
# | MONTANT_ANNUITE         | Montant de l’annuité de remboursement prévue                                     |
# | PRIX_BIEN               | Prix du bien financé par le crédit                                               |
# | AGE_VOITURE             | Âge du véhicule de l’emprunteur (si applicable)                                  |
# | POPULATION_REGION_RELATIVE | Densité de population relative de la région de résidence                       |
# | NOTE_CLIENT_REGION      | Note du client basée sur sa région                                               |
# | NOTE_CLIENT_REGION_VILLE| Note du client basée sur sa région + ville                                       |
# | SOURCE_EXTERNE_1        | Score externe de solvabilité (source 1)                                          |
# | SOURCE_EXTERNE_2        | Score externe de solvabilité (source 2)                                          |
# | SOURCE_EXTERNE_3        | Score externe de solvabilité (source 3)                                          |
# | APPARTEMENTS_MOYEN      | Moyenne normalisée de la surface/appartement de résidence                        |
# | ANNEE_CONSTRUCTION_MOYENNE | Année moyenne de construction du logement (normalisée)                         |
# | SURFACE_TOTALE          | Surface totale du logement (normalisée)                                          |
# | NB_CONNAISSANCES_30J    | Nombre de connaissances ayant eu un crédit observées sur 30 jours                |
# | NB_DEFAILLANCES_CONNAISSANCES_30J | Nombre de connaissances en défaut sur 30 jours                         |
# | DERNIER_CHANGEMENT_TEL_JOURS | Nombre de jours depuis le dernier changement de téléphone                   |
# | TYPE_REVENU             | Type de revenu de l’emprunteur (salarié, retraité, indépendant, etc.)            |
# | PROFESSION              | Profession déclarée de l’emprunteur                                              |
# | TYPE_ORGANISATION       | Type d’organisation de l’employeur                                               |

# %%
nom_col=selected_cols = [
    "CODE_GENDER",
    "DAYS_BIRTH",
    "DAYS_EMPLOYED",
    "DAYS_REGISTRATION",
    "DAYS_ID_PUBLISH",
    "NAME_EDUCATION_TYPE",
    "NAME_FAMILY_STATUS",
    "NAME_HOUSING_TYPE",
    "CNT_CHILDREN",
    "CNT_FAM_MEMBERS",
    "AMT_INCOME_TOTAL",
    "AMT_CREDIT",
    "AMT_ANNUITY",
    "AMT_GOODS_PRICE",
    "OWN_CAR_AGE",
    "REGION_POPULATION_RELATIVE",
    "REGION_RATING_CLIENT",
    "REGION_RATING_CLIENT_W_CITY",
    "EXT_SOURCE_1",
    "EXT_SOURCE_2",
    "EXT_SOURCE_3",
    "APARTMENTS_AVG",
    "YEARS_BUILD_AVG",
    "TOTALAREA_MODE",
    "OBS_30_CNT_SOCIAL_CIRCLE",
    "DEF_30_CNT_SOCIAL_CIRCLE",
    "DAYS_LAST_PHONE_CHANGE",
    "NAME_INCOME_TYPE",
    "OCCUPATION_TYPE",
    "ORGANIZATION_TYPE",
    "TARGET"
]

# %%
df=pd.read_csv("Archive/application_data.csv")[nom_col]

# %%
df.shape
# Out:
# (307511, 31)

# %%
df=df.rename(columns= {
    "CODE_GENDER": "SEXE",
    "DAYS_BIRTH": "AGE_JOURS",
    "DAYS_EMPLOYED": "ANCIENNETE_EMPLOI_JOURS",
    "DAYS_REGISTRATION": "ANCIENNETE_REGISTRE_JOURS",
    "DAYS_ID_PUBLISH": "ANCIENNETE_IDENTITE_JOURS",
    "NAME_EDUCATION_TYPE": "NIVEAU_ETUDES",
    "NAME_FAMILY_STATUS": "STATUT_FAMILIAL",
    "NAME_HOUSING_TYPE": "TYPE_LOGEMENT",
    "CNT_CHILDREN": "NB_ENFANTS",
    "CNT_FAM_MEMBERS": "NB_MEMBRES_FAMILLE",
    "AMT_INCOME_TOTAL": "REVENU_TOTAL",
    "AMT_CREDIT": "MONTANT_CREDIT",
    "AMT_ANNUITY": "MONTANT_ANNUITE",
    "AMT_GOODS_PRICE": "PRIX_BIEN",
    "OWN_CAR_AGE": "AGE_VOITURE",
    "REGION_POPULATION_RELATIVE": "POPULATION_REGION_RELATIVE",
    "REGION_RATING_CLIENT": "NOTE_CLIENT_REGION",
    "REGION_RATING_CLIENT_W_CITY": "NOTE_CLIENT_REGION_VILLE",
    "EXT_SOURCE_1": "SOURCE_EXTERNE_1",
    "EXT_SOURCE_2": "SOURCE_EXTERNE_2",
    "EXT_SOURCE_3": "SOURCE_EXTERNE_3",
    "APARTMENTS_AVG": "APPARTEMENTS_MOYEN",
    "YEARS_BUILD_AVG": "ANNEE_CONSTRUCTION_MOYENNE",
    "TOTALAREA_MODE": "SURFACE_TOTALE",
    "OBS_30_CNT_SOCIAL_CIRCLE": "NB_CONNAISSANCES_30J",
    "DEF_30_CNT_SOCIAL_CIRCLE": "NB_DEFAILLANCES_CONNAISSANCES_30J",
    "DAYS_LAST_PHONE_CHANGE": "DERNIER_CHANGEMENT_TEL_JOURS",
    "NAME_INCOME_TYPE": "TYPE_REVENU",
    "OCCUPATION_TYPE": "PROFESSION",
    "ORGANIZATION_TYPE": "TYPE_ORGANISATION",
    "TARGET":"cible"
}
)

# %%
df.shape
# Out:
# (307511, 31)

# %%
#df.to_csv("appli_data_fr.csv")

# %%
df=pd.read_csv("D:\\Home\\mabdraman\\Downloads\\appli_data_fr.csv")

# %%
df=df[:10000]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'SEXE', 'AGE_JOURS', 'ANCIENNETE_EMPLOI_JOURS',
#        'ANCIENNETE_REGISTRE_JOURS', 'ANCIENNETE_IDENTITE_JOURS',
#        'NIVEAU_ETUDES', 'STATUT_FAMILIAL', 'TYPE_LOGEMENT', 'NB_ENFANTS',
#        'NB_MEMBRES_FAMILLE', 'REVENU_TOTAL', 'MONTANT_CREDIT',
#        'MONTANT_ANNUITE', 'PRIX_BIEN', 'AGE_VOITURE',
#        'POPULATION_REGION_RELATIVE', 'NOTE_CLIENT_REGION',
#        'NOTE_CLIENT_REGION_VILLE', 'SOURCE_EXTERNE_1', 'SOURCE_EXTERNE_2',
#        'SOURCE_EXTERNE_3', 'APPARTEMENTS_MOYEN', 'ANNEE_CONSTRUCTION_MOYENNE',
#        'SURFACE_TOTALE', 'NB_CONNAISSANCES_30J',
#        'NB_DEFAILLANCES_CONNAISSANCES_30J', 'DERNIER_CHANGEMENT_TEL_JOURS',
#        'TYPE_REVENU', 'PROFESSION', 'TYPE_ORGANISATION', 'cible'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.isna().sum()
# Out:
# SEXE                                    0
# AGE_JOURS                               0
# ANCIENNETE_EMPLOI_JOURS                 0
# ANCIENNETE_REGISTRE_JOURS               0
# ANCIENNETE_IDENTITE_JOURS               0
# NIVEAU_ETUDES                           0
# STATUT_FAMILIAL                         0
# TYPE_LOGEMENT                           0
# NB_ENFANTS                              0
# NB_MEMBRES_FAMILLE                      0
# REVENU_TOTAL                            0
# MONTANT_CREDIT                          0
# MONTANT_ANNUITE                         0
# PRIX_BIEN                               7
# AGE_VOITURE                          6662
# POPULATION_REGION_RELATIVE              0
# NOTE_CLIENT_REGION                      0
# NOTE_CLIENT_REGION_VILLE                0
# SOURCE_EXTERNE_1                     5647
# SOURCE_EXTERNE_2                       26
# SOURCE_EXTERNE_3                     1995
# APPARTEMENTS_MOYEN                   5065
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df_categ=df.select_dtypes(include="object")
df_numeric=df.loc[:,df.columns.difference(df_categ.columns)]

# %%
df_categ.dtypes
# Out:
# SEXE                 object
# NIVEAU_ETUDES        object
# STATUT_FAMILIAL      object
# TYPE_LOGEMENT        object
# TYPE_REVENU          object
# PROFESSION           object
# TYPE_ORGANISATION    object
# dtype: object

# %%
df_numeric.shape
# Out:
# (356, 24)

# %%
df_numeric.corr()
# Out:
#                                    AGE_JOURS  AGE_VOITURE  \
# AGE_JOURS                           1.000000     0.058192
# AGE_VOITURE                         0.058192     1.000000
# ANCIENNETE_EMPLOI_JOURS             0.363475     0.011811
# ANCIENNETE_IDENTITE_JOURS           0.045144     0.092142
# ANCIENNETE_REGISTRE_JOURS           0.256721     0.026669
# ANNEE_CONSTRUCTION_MOYENNE          0.081766    -0.096541
# APPARTEMENTS_MOYEN                 -0.072070    -0.075408
# DERNIER_CHANGEMENT_TEL_JOURS        0.107920     0.062932
# MONTANT_ANNUITE                    -0.195880    -0.104091
# MONTANT_CREDIT                     -0.188172    -0.100519
# NB_CONNAISSANCES_30J                0.075977     0.055602
# NB_DEFAILLANCES_CONNAISSANCES_30J  -0.027526     0.137455
# NB_ENFANTS                          0.151301     0.045092
# NB_MEMBRES_FAMILLE                  0.100275     0.028999
# NOTE_CLIENT_REGION                  0.084137     0.071056
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", center=0)
plt.title("Matrice de corrélation")
plt.show()

# %%
sns.pairplot(df_numeric.iloc[:,:6])
